# %% [markdown]
# ## Instruções do projeto
# Faça uma função calculadora que os números e as operações serão feitas pelo usuário.
#
# O código deve ficar rodando infinitamente até que o usuário escolha a opção de sair.
#
# No início, o programa mostrará a seguinte lista de operações:
#
#   1: Soma
#
#   2: Subtração
#
#   3: Multiplicação
#
#   4: Divisão
#
#   0: Sair
#
# Digite o número para a operação correspondente e caso o usuário introduza qualquer outro, o sistema deve mostrar a mensagem “Essa opção não existe” e voltar ao menu de opções.
#
# Após a seleção, o sistema deve pedir para o usuário inserir o primeiro e segundo valor, um de cada.
#
# Depois precisa executar a operação e mostrar o resultado na tela.
#
# Quando o usuário escolher a opção “Sair”, o sistema irá parar.

# %%
def calculadora (num1, num2, opera):
  if (opera == 1):
    return num1 + num2
  elif (opera == 2):
    return num1 - num2
  elif (opera == 3):
    return num1 * num2
  elif (opera == 4):
    if(num2 == 0):
      return 0
    else:
      return num1 / num2
  else:
    return 0

loop = 1

while (loop == 1):
  print(" ")
  print("Opções de Calculos:")
  print(" ")
  print("1. SOMA")
  print("2. SUBTRAÇÃO")
  print("3. MULTIPLICAÇÃO")
  print("4. DIVISÃO")
  print("0. SAIR")
  print(" ")
  opera = float(input("Digite agora o operação deseja: "))
  print(" ")

  if (opera == 0):
    print("Obrigado por usar nossa calculadora!")
    print(" ")
    print("-----------------------------------------------------------------------------------")
    print(" ")
    break
  elif (opera > 4):
    print("Essa opção não existe!")
    print(" ")
    print("-----------------------------------------------------------------------------------")
    print(" ")
  else:
    num1 = float(input("Digite 1° numero: "))
    print(" ")
    num2 = float(input("Digite 2° numero: "))
    print(" ")

  resultado = calculadora (num1, num2, opera)

  if (opera == 1):
    print("O resultado da adição do numero", num1, "com o numero ", num2, "é: ", resultado, ".")
    print(" ")
    print("-----------------------------------------------------------------------------------")
    print(" ")
  elif (opera == 2):
    print("O resultado da subtração do numero", num1, "pelo o numero ", num2, "é: ", resultado, ".")
    print(" ")
    print("-----------------------------------------------------------------------------------")
    print(" ")
  elif (opera == 3):
    print("O produto da multiplicação do numero", num1, "com o numero ", num2, "é: ", resultado, ".")
    print(" ")
    print("-----------------------------------------------------------------------------------")
    print(" ")
  elif (opera == 4):
    if(num2 == 0):
      resultado=0
      print("Divisão por Zero! Este tipo de operação não está definida! Resultado = ", resultado)
      print(" ")
      print("-----------------------------------------------------------------------------------")
      print(" ")
    else:
      print("O produto da divisão do numero", num1, "pelo o numero ", num2, "é: ", resultado, ".")
      print(" ")
      print("-----------------------------------------------------------------------------------")
      print(" ")
  elif (opera == 0):
    loop = 0
  else:
    resultado= 0
#    print("Opção invalida! Resultado = ", resultado)
#    print(" ")
#    print("-----------------------------------------------------------------------------------")
#    print(" ")
# Out:
#
# Opções de Calculos:
#
# 1. SOMA
# 2. SUBTRAÇÃO
# 3. MULTIPLICAÇÃO
# 4. DIVISÃO
# 0. SAIR
#
# Digite agora o operação deseja: 1
#
# Digite 1° numero: 1
#
# Digite 2° numero: 1
#
# O resultado da adição do numero 1.0 com o numero  1.0 é:  2.0 .
#
# -----------------------------------------------------------------------------------
#
#
# Opções de Calculos:
#
# 1. SOMA
# 2. SUBTRAÇÃO
# 3. MULTIPLICAÇÃO
# 4. DIVISÃO
# 0. SAIR
#
# Digite agora o operação deseja: 2
#
# Digite 1° numero: 2
#
# Digite 2° numero: 1
#
# O resultado da subtração do numero 2.0 pelo o numero  1.0 é:  1.0 .
#
# -----------------------------------------------------------------------------------
#
#
# Opções de Calculos:
#
# 1. SOMA
# 2. SUBTRAÇÃO
# 3. MULTIPLICAÇÃO
# 4. DIVISÃO
# 0. SAIR
#
# Digite agora o operação deseja: 3
#
# Digite 1° numero: 2
#
# Digite 2° numero: 2
#
# O produto da multiplicação do numero 2.0 com o numero  2.0 é:  4.0 .
#
# -----------------------------------------------------------------------------------
#
#
# Opções de Calculos:
#
# 1. SOMA
# 2. SUBTRAÇÃO
# 3. MULTIPLICAÇÃO
# 4. DIVISÃO
# 0. SAIR
#
# Digite agora o operação deseja: 4
#
# Digite 1° numero: 4
#
# Digite 2° numero: 2
#
# O produto da divisão do numero 4.0 pelo o numero  2.0 é:  2.0 .
#
# -----------------------------------------------------------------------------------
#
#
# Opções de Calculos:
#
# 1. SOMA
# 2. SUBTRAÇÃO
# 3. MULTIPLICAÇÃO
# 4. DIVISÃO
# 0. SAIR
#
# Digite agora o operação deseja: 4
#
# Digite 1° numero: 4
#
# Digite 2° numero: 0
#
# Divisão por Zero! Este tipo de operação não está definida! Resultado =  0
#
# -----------------------------------------------------------------------------------
#
#
# Opções de Calculos:
#
# 1. SOMA
# 2. SUBTRAÇÃO
# 3. MULTIPLICAÇÃO
# 4. DIVISÃO
# 0. SAIR
#
# Digite agora o operação deseja: 0
#
# Obrigado por usar nossa calculadora!
#
# -----------------------------------------------------------------------------------
